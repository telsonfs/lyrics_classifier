# %%
import pandas as pd
import numpy as np
from time import time

# Realizando experimentos usando as vetorizações CountVectorizer e TF-IDF

from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split


from model.feature_engineering import FeatureEngineering
from model.preprocessing import Preprocessing
from model.visualization import Visualization
from model.model import Model
from model.metrics import Metrics

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# Out:
# [nltk_data] Downloading package punkt to /home/telson/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/telson/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
feature = FeatureEngineering()
preproc = Preprocessing()
visualization = Visualization()
model = Model()
metrics = Metrics()

# %%
df_funk = pd.read_csv("dataset/funk.csv")
df_gospel = pd.read_csv("dataset/gospel.csv")
df_sertanejo = pd.read_csv("dataset/sertanejo.csv")
df_bossa_nova = pd.read_csv("dataset/bossa_nova.csv")

# %%
df_funk_train, df_funk_valid = feature.split_train_test(df_funk, 0.2)
df_gospel_train, df_gospel_valid = feature.split_train_test(df_gospel, 0.2)
df_sertanejo_train, df_sertanejo_valid = feature.split_train_test(df_sertanejo, 0.2)
df_bossa_nova_train, df_bossa_nova_valid = feature.split_train_test(df_bossa_nova, 0.2)

df_funk_valid['genre'] = ["funk"]*len(df_funk_valid)
df_gospel_valid['genre'] = ["gospel"]*len(df_gospel_valid)
df_sertanejo_valid['genre'] = ["sertanejo"]*len(df_sertanejo_valid)
df_bossa_nova_valid['genre'] = ["bossa_nova"]*len(df_bossa_nova_valid)

df_genre_musics_valid = pd.concat([df_funk_valid, df_gospel_valid, df_sertanejo_valid, df_bossa_nova_valid])
df_genre_musics_valid.to_csv("valid/valid.csv")
# Out:
# /tmp/ipykernel_66079/137935989.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_funk_valid['genre'] = ["funk"]*len(df_funk_valid)
# /tmp/ipykernel_66079/137935989.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gospel_valid['genre'] = ["gospel"]*len(df_gospel_valid)
# /tmp/ipykernel_66079/137935989.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_funk_train['lyric'] = preproc.clean_lyric(df_funk_train.lyric)
df_funk_train['famous_word'] = [feature.famous_word(lyric) for lyric in df_funk_train.lyric.to_list()]
df_funk_train['total_words'] = [feature.total_words(lyric) for lyric in df_funk_train.lyric.to_list()]
df_funk_train['percent_originality'] = [feature.percent_originality(lyric) for lyric in df_funk_train.lyric.to_list()]
df_funk_train['genre'] = ["funk"]*len(df_funk_train)

df_gospel_train['lyric'] = preproc.clean_lyric(df_gospel_train.lyric)
df_gospel_train['famous_word'] = [feature.famous_word(lyric) for lyric in df_gospel_train.lyric.to_list()]
df_gospel_train['total_words'] = [feature.total_words(lyric) for lyric in df_gospel_train.lyric.to_list()]
df_gospel_train['percent_originality'] = [feature.percent_originality(lyric) for lyric in df_gospel_train.lyric.to_list()]
df_gospel_train['genre'] = ["gospel"]*len(df_gospel_train)

df_sertanejo_train['lyric'] = preproc.clean_lyric(df_sertanejo_train.lyric)
df_sertanejo_train['famous_word'] = [feature.famous_word(lyric) for lyric in df_sertanejo_train.lyric.to_list()]
df_sertanejo_train['total_words'] = [feature.total_words(lyric) for lyric in df_sertanejo_train.lyric.to_list()]
df_sertanejo_train['percent_originality'] = [feature.percent_originality(lyric) for lyric in df_sertanejo_train.lyric.to_list()]
df_sertanejo_train['genre'] = ["sertanejo"]*len(df_sertanejo_train)

df_bossa_nova_train['lyric'] = preproc.clean_lyric(df_bossa_nova_train.lyric)
df_bossa_nova_train['famous_word'] = [feature.famous_word(lyric) for lyric in df_bossa_nova_train.lyric.to_list()]
df_bossa_nova_train['total_words'] = [feature.total_words(lyric) for lyric in df_bossa_nova_train.lyric.to_list()]
df_bossa_nova_train['percent_originality'] = [feature.percent_originality(lyric) for lyric in df_bossa_nova_train.lyric.to_list()]
df_bossa_nova_train['genre'] = ["bossa_nova"]*len(df_bossa_nova_train)
# Out:
# /tmp/ipykernel_66079/3084106471.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_funk_train['lyric'] = preproc.clean_lyric(df_funk_train.lyric)
# /tmp/ipykernel_66079/3084106471.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_funk_train['famous_word'] = [feature.famous_word(lyric) for lyric in df_funk_train.lyric.to_list()]
# /tmp/ipykernel_66079/3084106471.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_genre_musics_train = pd.concat([df_funk_train, df_gospel_train, df_sertanejo_train, df_bossa_nova_train], ignore_index = True)
df_genre_musics_train.reindex()
df_genre_musics_train.to_csv("train/train.csv")

# %%
df_funk_train.describe()
# Out:
#        total_words  percent_originality
# count   640.000000           640.000000
# mean    139.050000            48.012156
# std      77.961934            21.375995
# min       4.000000             5.860000
# 25%      80.000000            31.030000
# 50%     127.000000            44.970000
# 75%     183.000000            65.305000
# max     523.000000           100.000000

# %%
df_gospel_train.describe()
# Out:
#        total_words  percent_originality
# count   640.000000           640.000000
# mean     98.900000            55.471141
# std      51.784518            19.166930
# min       1.000000            11.400000
# 25%      60.000000            40.000000
# 50%      89.000000            54.565000
# 75%     126.000000            71.715000
# max     338.000000           100.000000

# %%
df_sertanejo_train.describe()
# Out:
#        total_words  percent_originality
# count   640.000000           640.000000
# mean     92.759375            62.979422
# std      49.537974            21.552566
# min      28.000000            16.220000
# 25%      59.000000            42.745000
# 50%      81.000000            67.350000
# 75%     120.000000            82.610000
# max     791.000000            97.960000

# %%
df_bossa_nova_train.describe()
# Out:
#        total_words  percent_originality
# count   640.000000           640.000000
# mean     82.656250            67.262625
# std      75.824115            18.731333
# min      12.000000            11.220000
# 25%      45.000000            55.190000
# 50%      63.000000            70.290000
# 75%      90.250000            81.480000
# max     887.000000           100.000000

# %%
visualization.freq_dist(df_funk_train.famous_word.to_list(), 10)

# %%
visualization.freq_dist(df_gospel_train.famous_word.to_list(), 10)

# %%
visualization.freq_dist(df_sertanejo_train.famous_word.to_list(), 10)

# %%
visualization.freq_dist(df_bossa_nova_train.famous_word.to_list(), 10)

# %%
visualization.word_cloud(df_funk_train.famous_word.to_list(), 'funk')

# %%
visualization.word_cloud(df_sertanejo_train.famous_word.to_list(), 'sertanejo')

# %%
visualization.word_cloud(df_gospel_train.famous_word.to_list(), 'gospel')

# %%
visualization.word_cloud(df_bossa_nova_train.famous_word.to_list(), 'bossa_nova')

# %%
sns.displot(df_genre_musics_train, x= "percent_originality", hue="genre", element="step")

# %%
sns.displot(df_genre_musics_train, x= "total_words", hue="genre", element="step")

# %%
sns.displot(df_genre_musics_train, x="percent_originality", hue="genre", stat="probability")

# %%
sns.displot(df_genre_musics_train, x="total_words", hue="genre", stat="probability")

# %%
text_vect = model.train_count_vectorizer(df_genre_musics_train["lyric"])
x_train, x_test, y_train, y_test = train_test_split(text_vect, 
                                                 df_genre_musics_train["genre"],
                                                 test_size = 0.2, 
                                                 random_state = 42)

print('=' * 80)
print('BaggingClassifier')
baggin_count_vectorizer = metrics.benchmark(BaggingClassifier(), x_train, y_train, x_test, y_test)

print('=' * 80)
print('RandomForestClassifier')
randomf_count_vectorizer = metrics.benchmark(RandomForestClassifier(), x_train, y_train, x_test, y_test)

print('=' * 80)
print('KNeighborsClassifier')
kneighbors_count_vectorizer = metrics.benchmark(KNeighborsClassifier(), x_train, y_train, x_test, y_test)

print('=' * 80)
print('DecisionTreeClassifier')
decisiont_count_vectorizer = metrics.benchmark(DecisionTreeClassifier(), x_train, y_train, x_test, y_test)
# Out:
# ...
# BaggingClassifier
# ________________________________________________________________________________
# Training:
# BaggingClassifier()
# train time: 1.500s
# test time:  0.006s
# f1_score:   0.721
# *************** Classification Report ***************
#               precision    recall  f1-score   support
#
#   bossa_nova       0.66      0.78      0.72       123
#         funk       0.79      0.62      0.70       136
#       gospel       0.79      0.88      0.83       123
#    sertanejo       0.65      0.62      0.63       130
#
#     accuracy                           0.72       512
#    macro avg       0.72      0.72      0.72       512
# weighted avg       0.72      0.72      0.72       512
#
# Confusion Matrix
#
# ...
# RandomForestClassifier
# ________________________________________________________________________________
# Training:
# RandomForestClassifier()
# train time: 1.201s
# test time:  0.019s
# f1_score:   0.812
# *************** Classification Report ***************
# ...

# %%
text_vect = model.train_tf_idf(df_genre_musics_train["lyric"], 4)

results = []
x_train, x_test, y_train, y_test = train_test_split(text_vect, 
                                                 df_genre_musics_train["genre"],
                                                 test_size = 0.2, 
                                                 random_state = 42)

print('=' * 80)
print('BaggingClassifier')
baggin_tf_idf = metrics.benchmark(BaggingClassifier(), x_train, y_train, x_test, y_test)

print('=' * 80)
print('RandomForestClassifier')
randomf_tf_idf = metrics.benchmark(RandomForestClassifier(), x_train, y_train, x_test, y_test)

print('=' * 80)
print('KNeighborsClassifier')
kneighbors_tf_idf = metrics.benchmark(KNeighborsClassifier(), x_train, y_train, x_test, y_test)

print('=' * 80)
print('DecisionTreeClassifier')
decisiont_tf_idf = metrics.benchmark(DecisionTreeClassifier(), x_train, y_train, x_test, y_test)
# Out:
# ...
# BaggingClassifier
# ________________________________________________________________________________
# Training:
# BaggingClassifier()
# train time: 2.873s
# test time:  0.013s
# f1_score:   0.691
# *************** Classification Report ***************
#               precision    recall  f1-score   support
#
#   bossa_nova       0.66      0.69      0.67       123
#         funk       0.73      0.65      0.69       136
#       gospel       0.76      0.85      0.80       123
#    sertanejo       0.61      0.58      0.60       130
#
#     accuracy                           0.69       512
#    macro avg       0.69      0.69      0.69       512
# weighted avg       0.69      0.69      0.69       512
#
# Confusion Matrix
#
# ...
# RandomForestClassifier
# ________________________________________________________________________________
# Training:
# RandomForestClassifier()
# train time: 1.603s
# test time:  0.026s
# f1_score:   0.803
# *************** Classification Report ***************
# ...

# %%
model.save_model(randomf_tf_idf)

# %%
valid = pd.read_csv("valid/valid.csv")
# Out:
# ' \nViva la vida hoje, vou viver\nJogue sua mão pro alto, jogue seu copo pro alto\nViva hoje, vem viver\nNão pense no amanhã agora\nEssa é a nossa hora\nViva\nVou vivendo, vai vendo, o vento me leva\nPra onde eu me encontro, suave, né?\nNo momento, o tempo é a razão do momento\nMe lembro: tô tonto com duas mulher\nEu olhei pro meu copo, ficou meio roxo\nOu eu tô chapado, ele fala: Eu tô loco\nEla fala: Eu tô loco, tô ficando doido\nVou olhando pros lados, ham!\nLuzes de neon curtindo um baile funk\nBrisa boa o bastante pra lembrar de você\nTe vejo então indo até o chão\nVai parar meu coração\nViva la vida hoje, vou viver\nJogue sua mão pro alto, jogue seu copo pro alto\nViva hoje, vem viver\nNão pense no amanhã agora\nEssa é a nossa hora\nViva\nQuando isso aqui começar, não vai ter hora pra acabar\nQuero que saiba que a vibe positiva está no ar\nE a festa só está começando\nSe for firmeza é só ir chegando\nSão dez minas pra dois manos\nMais dez minas pra dois manos\nLuzes de neon cur
# ...

# %%
import pickle

#modelo = pickle.load(open('model.sav', 'rb'))
valid['lyric'] = preproc.clean_lyric(valid['lyric'])
# Out:
# 'copo canto sonhando imaginando naquele bar afogando mágoas olhar veio roubar primeiro segundo terceiro certeiro acertou calor tarou caô primeiro segundo terceiro agora aguentar vem devagar solta vem devagar solta vem devagar solta rebola vem devagar solta vem devagar solta vem devagar solta rebola tava canto copo provocou livinho provocou livinho embriagou olhos agora quero pouquinho quero pouquinho vem devagar solta vem devagar solta vem devagar solta vem devagar solta rebola vem devagar solta vem devagar solta vem devagar solta rebola tava canto copo provocou livinho provocou livinho embriagou olhos agora quero pouquinho quero pouquinho vem devagar solta vem devagar solta vem devagar solta vem devagar solta rebola vem devagar solta vem devagar solta vem devagar solta rebola'

# %%
txt = valid['lyric'][3]
txt
# Out:
# 'tudo mudou aí mudo nada bike virou r descalço hoje sobe marchas vem papo malícia pra dá nada joga bumbum cota amassa placa acha forgando nave comigo imagina amiga vínculo digo muitos falsos poucos amigos nessa vida corre perigo dá abraço amigo costas inimigo desculpa geral verdade sei neném andei skate hoje dia pousa porque tô nave tá suave maserati mar corta iate paty verdade implorando night tá suave maserati mar corta iate paty verdade kevin jorgin night vai segurando'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

count_vect = TfidfVectorizer(ngram_range=(1, 4), use_idf=True, lowercase=True, min_df=2, max_df=0.95)
count_vect.fit(valid['lyric'])
# Out:
# array(['funk'], dtype=object)

# %%
text_vect = count_vect.transform([txt])

modelo.predict(text_vect)
# Out:
# array(['funk'], dtype=object)
