# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd


from model.feature_engineering import FeatureEngineering
from model.preprocessing import Preprocessing
from model.visualization import Visualization
from model.model import Model
from model.metrics import Metrics
# Out:
# [nltk_data] Downloading package punkt to /home/telson/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/telson/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
feature = FeatureEngineering()
preproc = Preprocessing()
visualization = Visualization()
model = Model()
metrics = Metrics()

# %%
df_genre_musics_train = pd.read_csv("train/train.csv")
df_genre_musics_train
# Out:
#       Unnamed: 0                                              lyric  \
# 0              0  hoje vim poder falar poder contar passou falar...
# 1              1  vê mexe piri pipiri pipiri piri piriguete rebo...
# 2              2  contexto putaria novinha vou explicar hoje mir...
# 3              3  malha funk muleques dengoso vem pra cá tchutch...
# 4              4  olha pisca rouba brisa visualiza mlk mídia gar...
# ...          ...                                                ...
# 2555        2555  tristeza senhora desde samba samba assim lágri...
# 2556        2556  quiet nights of quiet stars quiet chords from ...
# 2557        2557  quer ser namorada ah linda namorada poderia se...
# 2558        2558  morena flor dê cheirinho cheinho amor dê todo ...
# 2559        2559  vez lobo mal resolveu jantar alguém vintém arr...
#
#      famous_word  total_words  percent_originality       genre
# 0           hoje          149                54.36        funk
# ...

# %%
count_vectorizer = CountVectorizer()
tf_idf_vectorizer = TfidfVectorizer()

# %%
text_vect = model.vectorizer(count_vectorizer, df_genre_musics_train["lyric"])
#df_count_vectorizer = metrics.experiments_models(df_genre_musics_train, text_vect)
#df_count_vectorizer

# %%
import numpy as np
from time import time
from sklearn import metrics
from sklearn.model_selection import cross_val_score

from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

def experiments_models(genre, text_vect):
    k = 10
    
    results = {
        'model': ['BaggingClassifier', 'RandomForestClassifier', 'LogisticRegression', 'KNeighborsClassifier', 'DecisionTreeClassifier'],
        'score': []
    }
    
    scores = cross_val_score(BaggingClassifier(), text_vect, genre, cv = k)
    score = np.mean(scores)
    results['score'].append(score)
    print(f'BaggingClassifier: {score}')
    print('=' * 80)
    
    scores = cross_val_score(RandomForestClassifier(), text_vect, genre, cv = k)
    score = np.mean(scores)
    results['score'].append(score)
    print(f'RandomForestClassifier: {score}')
    print('=' * 80)
    
    scores = cross_val_score(LogisticRegression(), text_vect, genre, cv = k)
    score = np.mean(scores)
    results['score'].append(score)
    print(f'LogisticRegression: {score}')
    print('=' * 80)

    scores = cross_val_score(KNeighborsClassifier(), text_vect, genre, cv = k)
    score = np.mean(scores)
    results['score'].append(score)
    print('=' * 80)
    print(f'KNeighborsClassifier: {score}')
    
    scores = cross_val_score(DecisionTreeClassifier(), text_vect, genre, cv = k)
    score = np.mean(scores)
    results['score'].append(score)
    print('=' * 80)
    print(f'DecisionTreeClassifier: {score}')

    return results

# %%
text_vect = model.vectorizer(count_vectorizer, df_genre_musics_train["lyric"])
df_count_vectorizer = pd.DataFrame(data = model.experiments_models(df_genre_musics_train['genre'], text_vect))
df_count_vectorizer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_32336/2312932353.py in <module>
#       1 text_vect = model.vectorizer(count_vectorizer, df_genre_musics_train["lyric"])
# ----> 2 df_count_vectorizer = pd.DataFrame(data = experiments_models(df_genre_musics_train['genre'], text_vect))
#       3 df_count_vectorizer
#
# NameError: name 'experiments_models' is not defined

# %%
text_vect = model.vectorizer(tf_idf_vectorizer, df_genre_musics_train["lyric"])
df_tf_idf = pd.DataFrame(data= experiments_models(df_genre_musics_train['genre'], text_vect))
df_tf_idf
# Out:
# ...
# BaggingClassifier
# ...
# RandomForestClassifier
# ...
# LogisticRegression
# ...
# KNeighborsClassifier
# ...
# DecisionTreeClassifier
#                     model     score
# 0       BaggingClassifier  0.707812
# 1  RandomForestClassifier  0.813281
# 2      LogisticRegression  0.836328
# 3    KNeighborsClassifier  0.683984
# 4  DecisionTreeClassifier  0.625781
